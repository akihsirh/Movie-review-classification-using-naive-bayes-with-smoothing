# %% [markdown]
# # Naïve Bayes with smoothing
#
# ### Authors: Anjali Singh, Bhagyashri Nivdunge, Hrishika Shetty

# %% [markdown]
# # Introduction

# %% [markdown]
# This problem set has two aims:
# - Learn to understand Naive Bayes
# - Learn to handle text, a form of data that does not come as a table of numbers.
#
# You will implement your own Naive Bayes classifier and use this for categorizing Rotten Tomatoes reviews into rotten and fresh ones. Finally, you also find the optimal smoothing parameter.

# %% [markdown]
# # Rotten Tomatoes

# %% [markdown]
# Our first task is to load, clean and explore the Rotten Tomatoes movie reviews data. Please familiarize yourself a little bit with the webpage. Briefly, approved critics can write reviews for movies, and evaluate the movie as "fresh" or "rotten". The webpage normally shows a short "quote" from each critic, and whether it evaluates the movie as fresh or rotten. You will work on these quotes below.
# The central variables for our purpose in rotten-tomatoes.csv are the following:

# %% [markdown]
# fresh evaluation: 'fresh' or 'rotten'
# quote short version of the review
# There are more variables like links to IMDB.

# %% [markdown]
# # 1 Explore and clean the data

# %% [markdown]
# First, let's load data and take a closer look at it.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction import stop_words
import os
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

# %%
#path = os.getcwd()
#print(path)
data= pd.read_csv('rotten-tomatoes.csv.bz2')

# %%
data.sample(4)
# Out:
#             critic   fresh    imdb  \
# 3260  Rick Groen    fresh   117628
# 1264  Kevin Thomas  rotten  110516
# 1524  Peter Rainer  fresh   114924
# 3996  Ty Burr       fresh   58946
#
#                                                                                                                    link  \
# 3260  http://www.globeandmail.com/servlet/ArticleNews/movie/MOVIEREVIEWS/19960823/TAONEE
# 1264  http://articles.latimes.com/1994-08-31/entertainment/ca-33047_1_milk-money
# 1524  http://www.calendarlive.com/movies/reviews/cl-movie960406-234,0,636778.story
# 3996  http://www.boston.com/ae/movies/articles/2004/02/27/65_classic_battle_of_algiers_still_electrifies_and_challenges
#
#             publication  \
# 3260  Globe and Mail
# 1264  Los Angeles Times
# 1524  Los Angeles Times
# 3996  Boston Globe
#
#                                                                                                                                                              quote  \
# 3260  Edward Burns returns to the themes of family and love that he examined in The Brothers McMullen.
# 1264  Only the least demanding audiences can be expected to buy into Milk Money.
# 1524  Bullock is a genuinely engaging performer, which at least gives the treacle some minty freshness.
# 3996  The chafing, mutually uncomprehending collision of Western occupiers and Muslim occupied has never been captured with such dispassionate, thrilling clarity.
#
#               review_date       rtid  \
# 3260  2002-04-12 00:00:00  13832
# 1264  2013-05-22 00:00:00  11257
# 1524  2001-02-13 00:00:00  10076
# 3996  2004-02-27 00:00:00  133039722
#
#                                                title
# 3260  She's the One
# 1264  Milk Money
# 1524  While You Were Sleeping
# 3996  La Battaglia di Algeri (The Battle of Algiers)

# %% [markdown]
# 2. print out all variable names.

# %%
data.columns
# Out:
# Index(['critic', 'fresh', 'imdb', 'link', 'publication', 'quote',
#        'review_date', 'rtid', 'title'],
#       dtype='object')

# %% [markdown]
# 3. Create a summary table (maybe more like a bullet list) where you print out the most important summary statistics for the most interesting variables. The most interesting facts you should present should include:
#     - number of missings for fresh and quote
#     - all different values for fresh/rotten evaluations
#     - counts or percentages of these values
#     - number of zero-length or only whitespace quote-s
#     - minimum-maximum-average length of quotes (either in words, or in characters). (Can you do this as an one-liner?)
#     - how many reviews are in data multiple times. Feel free to add more 􏰃gures you consider relevant.

# %%
print(" \033[1m- The number of missings for fresh: \033[0m", data[data.fresh.isna() == True], sep="\n", end="\n\n")
print(" \033[1m- The number of missings for quote: \033[0m", data[data.quote.isna() == True], sep="\n", end="\n\n")
print(" \033[1m- All different values for fresh/rotten evaluations: \033[0m", data.fresh.value_counts(), sep="\n", end="\n\n")
print(" \033[1m- Percentage values for fresh/rotten evaluations: \033[0m", data.fresh.value_counts(normalize=True)*100, sep="\n", end="\n\n")
print(" \033[1m- Number of zero length or only white-space quotes: \033[0m", 
      data[(data.quote == "") | (data.quote.str.isspace())], sep="\n", end="\n\n")
data['quote_length'] = data['quote'].apply(len)
print(" \033[1m- Minimum-maximum-average length of quotes (either in words, or in characters):\n\033[0m", 
      "Mean = ",data.quote_length.mean(), "\n", 
      "Minimum = ",data.quote_length.min(), "\n", 
      "Maximum = ",data.quote_length.max(), "\n", end="\n\n")
print("\033[1m - Reviews in data multiple times:\n\033[0m", data[data.duplicated(subset=None, keep='first')][['quote']].count(), end="\n")
# Out:
#  - The number of missings for fresh:
# Empty DataFrame
# Columns: [critic, fresh, imdb, link, publication, quote, review_date, rtid, title]
# Index: []
#
#  - The number of missings for quote:
# Empty DataFrame
# Columns: [critic, fresh, imdb, link, publication, quote, review_date, rtid, title]
# Index: []
#
#  - All different values for fresh/rotten evaluations:
# fresh     8389
# rotten    5030
# none      23
# Name: fresh, dtype: int64
#
#  - Percentage values for fresh/rotten evaluations:
# fresh     62.408868
# rotten    37.420027
# none      0.171105
# Name: fresh, dtype: float64
#
#  - Number of zero length or only white-space quotes:
# Empty DataFrame
# Columns: [critic, fresh, imdb, link, publication, quote, review_date, rtid, title]
# Index: []
#
#  - Minimum-maximum-average length of quotes (either in words, or in characters):
#  Mean =  121.23128998660914
#  Minimum =  4
#  Maximum =  256
#
#
#  - Reviews in data multiple times:
#  quote    596
# dtype: int64

# %% [markdown]
# Now when you have an overview what you have in data, clean it by removing all the inconsistencies the table reveals. We have to ensure that the central variables, quote and fresh are not missing, quote is not an empty string (or just contain spaces and such), and all rows are unique.
# I recommend to do it as a standalone function so you can use the same function for another similar dataset (such as test data).

# %%
def clean_data(dataframe):
    #eliminate duplicate rows
    data.drop_duplicates(keep = 'first', inplace = True) 
    data_new = data[data.fresh!='none']
    #drop rows where column value for fresh and quote are missing or null
    data_new.dropna(subset = ['fresh','quote'],inplace=True)
    #write a code to remove whitespace. 
    data_new = data_new[~data_new.quote.str.isspace()]
    return data_new

# %%
data_new = clean_data(data)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# # 2 Naive Bayes

# %% [markdown]
# Now where you are familiar with the data, it's time to get serious and implement the Naive Bayes classifier from scratch. But first things first.

# %% [markdown]
# 2. Convert your data (quotes) into bag-of-words. Your code should look something like this:

# %%
stop_list = list(stop_words.ENGLISH_STOP_WORDS)
other_words = ['movie','movies','film','films','story','like','way','just','make','makes','director','comedy','picture',
              'characters','good','way','action','time','picture','really','funny','characters','character','performances',
              'does','doesn','isn','work','don','best','new','little','feel','plot','script','thriller']

stop_list.extend(other_words)
frozen_stop = frozenset(stop_list)

vectorizer = CountVectorizer(binary=True,stop_words=frozen_stop)
X = vectorizer.fit_transform(data_new.quote.values)
words = vectorizer.get_feature_names()

# x = data_new.drop(columns='fresh')
Y = data_new.fresh

# %% [markdown]
# 3. Split your work data and target (i.e. the variable fresh) into training and validation chunks (80/20 or so).

# %%
#splitting into training and test data 
from sklearn.model_selection import train_test_split
train_x,val_x,train_y,val_y = train_test_split(X, Y, test_size = 0.2)

# %% [markdown]
# 4. Compute the unconditional (log) probability that the tomato is fresh/rotten, log Pr(F), and log Pr(R). These probabilities are based on the values of fresh alone, not on the words the quotes contain.

# %%
#calculating log probability that the tomato is fresh
prF = np.log(len(train_y[train_y=='fresh'])/len(train_y))
prR = np.log(len(train_y[train_y=='rotten'])/len(train_y))

# %% [markdown]
# 5. For each word w, compute log Pr(w|F) and log Pr(w|R), the (log) probability that the word is present in a fresh/rotten review. These probabilities can easily be calculated from counts of how many times these words are present for each class.
# Hint: these computations are based on your BOW-s X. Look at ways to sum along columns in this matrix.

# %%
#fresh count and rotten count
fresh_count = train_x[np.where(train_y == 'fresh')].shape[0]
rotten_count = train_x[np.where(train_y == 'rotten')].shape[0]

#log probability that the word is present in fresh/rotten review
prWF = np.log(train_x[np.where(train_y == 'fresh')].toarray().sum(axis=0) / fresh_count)
prWR = np.log(train_x[np.where(train_y == 'rotten')].toarray().sum(axis=0)/ rotten_count)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log
#   import sys

# %% [markdown]
# Now we are done with the estimator. Your fitted model is completely described by these four probability vectors: log Pr(F), log Pr(R), log Pr(w|F), log Pr(w|R). Let's now turn to prediction, and pull out your validation data (not the test data!).

# %% [markdown]
# 6. For both destination classes, F and R, compute the log-likelihood that the quote belongs to this class. log-likelihood is what is given inside the brackets in equation (1) on slide 28, and the equations on Schutt "Doing Data Science", page 102. In lecture notes it is explained before the email classification example (and in the example too). On the slides we have the log-likelihood essentially as (although we do not write it out):

# %%
import re
arr_val_x = val_x.toarray()

# %%
#empty arrays for saving log likelyhood
log_likehood_F = []
log_likehood_R = []

# log likelyhood of the quote 
for word_index in np.arange(arr_val_x.shape[0]):
    val_text = arr_val_x[word_index]
    prTextF = 0.0
    prTextR = 0.0
    for index, word in enumerate(val_text,start=0):
        if word == 0:
            continue
        if np.isfinite(prWF[index]):
            prTextF += prWF[index]
        if np.isfinite(prWR[index]):
            prTextR += prWR[index]
    prTextF += prF
    prTextR += prR
    log_likehood_F.append(prTextF)
    log_likehood_R.append(prTextR)

# %% [markdown]
# 7. Print the resulting confusion matrix and accuracy (feel free to use existing libraries).

# %%
predicted_target = []

#calculating confusion matrix and accuracy
for index in np.arange(len(log_likehood_F)):
    if log_likehood_F[index] > log_likehood_R[index]:
        predicted_target.append('fresh')
        fresh_count+=1
    else:
        predicted_target.append('rotten')
        rotten_count+=1
predicted_target = np.array(predicted_target)

print(type(predicted_target))
print(type(val_y))
print(confusion_matrix(val_y, predicted_target))
print(accuracy_score(val_y, predicted_target))
# Out:
# <class 'numpy.ndarray'>
# <class 'pandas.core.series.Series'>
# [[651 904]
#  [430 580]]
# 0.47992202729044836

# %% [markdown]
# # 3 Interpretation

# %% [markdown]
# Now it is time to look at your fitted model a little bit closer. NB model probabilities are rather easy to understand and interpret. The task here is to find the best words to predict a fresh, and a rotten review. And we only want to look at words that are reasonably frequent, say more frequent than 30 times in the data.

# %% [markdown]
# 1. Extract from your conditional probability vectors log Pr(w|F) and log Pr(w|R) the probabilities that correspond to frequent words only.

# %%
#log probability value when word frequency is 30 times and review is fresh
fresh_baseline = np.log(30/fresh_count)
#log probability value when word frequency is 30 times and review is rotten
rotten_baseline = np.log(30/rotten_count)

#vector of probabilities of most frequent words when review is fresh
freq_fresh = prWF[prWF > fresh_baseline]

#vector of probabilities of most frequent words when review is rotten
freq_rotten = prWR[prWR > rotten_baseline]

# %% [markdown]
# 2. Find 10 best words to predict F and 10 best words to predict R. Hint: imagine we have a review that contains just a single word. Which word will give the highest weight to the probability the review is fresh? Which one to the likelihood it is rotten?
# Comment your results.

# %%
#get indexes of top 10 values
index_fresh = np.argsort(prWF)[-10:]
top_10_fresh = [words[i] for i in index_fresh]
print(top_10_fresh)

index_rotten = np.argsort(prWR)[-10:]
top_10_rotten = [words[i] for i in index_rotten]
print(top_10_rotten)
# Out:
# ['love', 'screen', 'entertainment', 'world', 'american', 'performance', 'life', 'entertaining', 'fun', 'great']
# ['thing', 'effects', 'old', 'hard', 'real', 'end', 'audience', 'better', 'long', 'bad']

# %% [markdown]
# 3. Print out a few missclassied quotes. Can you understand why these are misclassified?

# %%
# we print out the rows from our dataset that have mismatches between labels and predictions
result = (predicted_target == val_y)
data_new.loc[list(result[result == False].index)][['quote','fresh']]
# Out:
#                                                                                                                                                                                                                                                                  quote  \
# 11224  The movie understands that the story really is about the killer's point of view. It is not the story of a crime, not a docudrama, not a sociological essay.
# 12701  This 1940 film is one of Ernst Lubitsch's finest and most enduring works, a romantic comedy of dazzling range.
# 746    A delicacy, a passionate and compassionate study of erotica.
# 12985  Hopefully it's three strikes and you're out for The Punisher, as this latest attempt at creating another comic book franchise will prove once and for all that maybe this character just doesn't deserve the big screen treatment.
# 12536  Its willingness to take risks, and its insights into the frailties and confusions of teenage friendships, lift the film right out of the rut.
# 6430   Such Greenaway films as "The Cook, The Thief, His Wife & Her Lover," "Prospero's Books" and now this make one wonder if they're really as deep as they pretend to be. Perhaps, as his actors, this emperor has no clothes.
# 898    Brings the popular TV series to the screen with a barrage of spectacular special effects, a slew of fantastic monsters, a ferociously funny villain -- and, most important, a refreshing lack of pretentiousness.
# 8319   Mr. Bolt has reduced the vast upheaval of the Russian Revolution to the banalities of a doomed romance.
# 7427   Burning is too good for such a wretched fiasco; only a surgical nuclear strike could suitably destroy what has to be one of the most enervating comedies ever made.
# 10868  Angelopoulos' meditation on the meaning of one man's life is genuinely hypnotic in its way of transcending ordinary narrative.
# 5      As Lion King did before it, Toy Story revived the art of American children's animation, and ushered in a set of smart movies that entertained children and their parents. It's a landmark movie, and doesn't get old with frequent repetition.
# 4401   A nod to such noir crime classics as Stanley Kubrick's "The Killing," the movie's more than savvy sensationalism. Suspense, horror and humor are expertly interwoven.
# 4324   The movie's basic joke holds that the overbearing, unselfconscious Americans will do anything and say anything (and usually as loudly as possible), while the timorous British are nearly too polite to breathe.
# 3767   While the actors do what they can, too many characters come off as concepts, not people.
# 9047   A sweet little movie about characters who really seem to be people, and that sort of verisimilitude is rarer than it ought to be nowadays.
# 12888  Ms. Winslet is, by contrast, champagne and caviar for moviegoing grown-ups with good taste.
# 12645  You can't take a script flimsy enough for a Kate Hudson and Matthew McConaughey vehicle and expect a couple of real thoroughbreds like Thompson and Hoffman not to shred it to pieces.
# 80     A well-modulated charmer.
# 4103   The musical numbers woven into the fantasy are generally solid, with at least two or three likely hit tunes standing out in the half-dozen songs.
# 4553   In its excesses and extravagances, its fascination with sex, religion, celebrity, bad taste and making a whole lot of money, there is no more American story than that of combative pornographer and Hustler magazine publisher Larry Flynt.
# 8106   Dante is perhaps the first filmmaker since Frank Tashlin to base his style on the formal free-for-all of animated cartoons; he is also utterly heartless.
# 6842   Rarely has so much of so little consequence been so closely examined.
# 9586   Lasseter and Pixar broke new technical and aesthetic ground in the animation field with Toy Story, and here they surpass it in both scope and complexity of movement while telling a story that overlaps Antz in numerous ways.
# 9957   This charming romantic comedy with a Los Angeles setting cuts between seemingly unconnected miniplots the way some Robert Altman movies do.
# 12085  The only thing the Farrellys get right is the obsession, but even the most forgiving Red Sox fan will agree their team deserved more than this.
# 11500  Ravich's pacing is off.
# 10221  It's essentially a series of shorts linked together, but this doesn't deny the movie's deft examination of the insane minutia that plague contemporary workers.
# 4263   Despite protests from the Catholic Church (which whines about any movie that portrays priests as anything less-than-pure), Sleepers, which represents two and one-half hours of gripping entertainment, is well worth the price of admission.
# 4070   As an episode of The Wonderful World of Disney, it would be fine, but as a major motion picture, it's disappointing.
# 6473   On any level, earthly or otherwise, the ingenious new animated Hercules is pretty divine.
# 7730   It's tainted by a fair amount of middlebrow stuffiness, but it's a fleet piece of storytelling and serves to enshrine one of the great ham performances of all time, Charles Laughton's Captain Bligh.
# 1030   Young Benny has a nice smile, and she and Jack seem like pleasant people, but in the end (and in the beginning and in the middle) it's hard to get worked up about them.
# 9509   A few too many moralistic foreshadowings, but most of the time Cox's situations and characters develop on their own eloquently entropic terms.
# 3720   To see Gone With the Wind on a big screen again is to weep for the fearlessness with which Hollywood once believed the sublime was possible.
# 8405   A dazzling retelling of the J.M. Barrie tale.
# 13208  Snow Falling on Cedars is a motion picture of great thematic and visual richness.
# 5225   Polanski's film suggests that the rules of the game are written in some strange, untranslatable language, and that everyone's an alien and, ultimately, a victim.
# 6156   A tepid fourth entry in the popular 1980s series that is decidedly showing its age.
# 8275   It's not surprising that they haven't got around to changing the plot formula, only the scenery.
# 1596   Lee is a great self-promoter. After all his press releases and all his interviews, we are given films that are sketchy, unfelt and distancing -- incidents in Lee's career, the only drama that really interests him.
# 9448   Washington and Ms. Bening play smart, interesting characters who never quite connect, while Willis turns himself into the loosest military cannon this side of Dr. Strangelove.
# 6604   [Aniston] has the rare gift of getting you to root for her in the most trying of circumstances, a quality that will stand her in good stead when she progresses to better material.
# 12480  This Wayne Wang-directed movie hands Sarandon one of the richest comic-dramatic opportunities of her career -- while also confirming Portman as one of her own generation's best and brightest.
# 11107  Disney has struck once again, taking a passably entertaining cartoon and turning it into a motion picture so lifeless that it's almost unwatchable.
# 6413   Two major issues here: The boy, Marty (Jason Dolley), is a patronizing do-gooder, and the dog, a beagle-looking fella, doesn't do much that's special.
# 12570  Deneuve, without much dialog, handles a very difficult chore with insight and tact.
# 348    Certain words should be reserved for special occasions. 'Abysmal' is one of them, and Georgia Rule is as special as such occasions get.
# 10076  This prom-night balloon of a movie floats easily above the year's other exercises in '50s nostalgia. If you dare reach for it, it will land smartly in your heart.
# 7320   Writer-director James Toback must believe his audience is hopelessly prudish if he thinks this pedantic story, which takes place over several hours in a Manhattan loft, is provocative.
# 9148   As Chan moved from Hong Kong to Hollywood, something got lost in the translation.
# 2319   That Woody Allen found time to be remotely funny -- in the midst of his highly publicized legal troubles -- surely merits some kind of professional award.
# 12852  The intriguing (if not always successful) result is an oddly contemplative picture about a horribly bellicose time.
# 8620   Woe be to the child who doesn't mist up at this movie, since it's been made if not with zip, wit, or imagination, then at least with sweetness. But I hope no one will think the film is an adequate replacement for White's book. That would be a crime.
# 10553  It may not be for everyone -- the movie requires a high tolerance for statements such as 'there's only one instant, and it's now, and it's eternity' -- but it's like nothing else in theaters right now.
# 8507   An artless, non-stop barrage of off-the-wall situations, funny and unfunny jokes, generally effective and sometimes hilarious sight gags and bawdy non sequiturs.
# 10003  Wildly imaginative, gut-wrenchingly scarifying and profoundly primal (not to mention funny), David Cronenberg's The Fly is a movie that whacks you in the solar plexus and leaves you gasping.
# 6194   Based on a novel by British mystery writer P.D. James, Children of Men is a filmmaking feat. In the midst of mayhem, director Alfonso Cuaron delivers subtle and jarring images, while exploring complex emotional rhythms.
# 3003   Director Margarethe von Trotta effortlessly weaves history and personal events into a tapestry full of emotion and irony.
# 11441  I suppose there is a market for this sort of thing among bubblebrained adolescents of all ages, but it takes a good chase scene indeed to rouse me from the lethargy induced by dozens and dozens of essentially similar sequences.
# 12500  Both visually spectacular and staggeringly awful.
# 11229  "Radio Days" is so ambitious and so audacious that it almost defies description.
# 1263   Every character shines with such dazzling intensity and such inexhaustible comic invention that the movie becomes tiresome, like too many clowns.
# 7914   Brooks' dialog is wonderful throughout and all the characters carry off their assignments beautifully, even down to Danny De Vito and Norman Bennett as MacLaine's other suffering suitors.
# 10685  Dick Tracy is Batman in a fedora -- a much-ballyhooed cartoon noir that's as skimpy on substance as it is burgeoning with jujube-colored, jutt-jawed style.
# 10659  An issue movie, a comedy, and a love story, this is pretty good at being all three.
# 4130   It is when the film [based on the book by Mary Norton] dives deeply into the realms of fantasy that it is most enjoyable.
# 8183   The film is an authentic children's entertainment and quite the merriest of its kind that Hollywood has turned loose on the nation's screens in a long time.
# 10288  Likeable.
# 63     Among the better of the 17 Bonds and, perhaps more important for today's audience, a dynamic action entry in its own right, this first 007 adventure in six years breathes fresh creative and commercial life into the 33-year-old series.
# 1188   A crackling thriller that feels unusually attuned to its lowlife characters.
# 9750   This is sensational cinema: crowds swarming among pyramids in eye-popping 3-D, camerawork that's distinctly Spielbergian in its fluidity.
# 12309  Noyce has the skill to keep the plot percolating and overcome its occasional missteps.
# 4389   A brash, brutal crime-caper film, Reservoir Dogs has enough raw energy for 10 motion pictures and more than enough rough stuff to traumatize the sensitive. But not only does Dogs have teeth, it has brains.
# 2651   While the film's first half entices with its secrets, the second half falls into a predictable narrative that refuses to even suggest possibilities.
# 5701   While the movie's inspirations might be glam-Hollywood action fantasies, Night Watch fairly wallows in damp, post-Soviet decay.
# 1436   Class has its place, but some of us prefer our cut-'em-ups a little more lowdown.
# 11501  The Astronaut's Wife is ridiculously derivative.
# 11606  Superlatively well-made.
# 7920   Maybe the problem of the pacing is simply the nature of the beast these days with expensive period pieces. Once the difficult details are all in place, it may be too much to expect a director to resist milking every scene for more than it's worth.
# 3867   Because we are bound by gravity and the limitations of our bodies, because we live in a world where the news is often bad and the prospects disturbing, there is a need for another world somewhere, a world where Fred Astaire and Ginger Rogers live.
# 561    A masterful psychological study, the depth of which can only fully be appreciated on repeat viewings.
# 3391   A significant improvement over the first Snake Plisskin adventure.
# 11706  It's far from his best work, and holds together about as well as a Clinton cabinet, but it's still thoroughly entertaining.
# 5272   The film grows more unsettling when it becomes apparent that the child killer Beckert is something of a child himself, forcing the audience into something beyond complicity, something dangerously close to identification.
# 2607   Sifting through the bloody, pulpy trash of True Romance -- should you care to -- you'll find amusing, smart-alecky nuggets planted by screenwriter Quentin Tarantino.
# 3868   All the minor players are such skilled comedians that they are able to extract merriment from this none too original comedy of errors.
# 8835   You see garbage bags filled with cash, a lot of avid cocaine snorting and fleeting glimpses of Warhol and Truman Capote, but it all feels ho-hum.
# 12411  There's no song in Repo!'s heart -- plus, it's disembodied and squashed on the floor.
# 4182   A bargian basement Ghost, a hybrid of the earnest nature of an inspirational play and the sleek calculation of a Lifetime TV movie.
# 6977   A highly romantic, deeply melancholy drama, the film offers psychological and existential insights about the inevitable effects - and price - of life choices.
# 12083  The Curse of the Bambino lives. And by now, it's spread to the backlot.
# 8326   A sumptuously produced period piece that is also a rich tapestry of childhood memoirs and moods, fear and fancy, employing all the manners and means of the best of cinematic theatrical from high and low comedy to darkest tragedy.
# 11259  With its austere look and the absence of music, The Iron Giant is something new, arresting and quite wondrous in the way of animated movies.
# 77     A shrewd new depiction of 'office sex,' as well as an utterly positive view of the idea that a president's character is important.
# 4399   The movie feels like it's going to be terrific, but Tarantino's script doesn't have much curiosity about these guys.
# 1002   This is an occasion when it's far better to see the trailer and skip the actual film. Once the opening credits start rolling, it's all downhill.
# 10623  Like its cinematic kin, Frost/Nixon and Doubt, this, too, is a delicately crafted, prestige project whose translation to screen doesn't deliver the original's amazements.
# 9542   There is no place for depth or nuance in this slickly engineered complacency machine.
# 1925   Even if the sequel doesn't offer the delight of discovery, the trip back to Chateau Addams is more than the dead end it could have been.
# 4266   Though Last Crusade lacks the novelty of Raiders (and, by the way, the flat-out breathless pacing of Temple of Doom), it's an entertaining capper to the trilogy.
# 2993   The film is ugly on so many levels -- from art direction to human values -- that it's hard to know where to begin.
# 3469   I'll let you in on a little secret that film critics have known for years. A major studio production, released in August with top-list stars, is almost certain to be a gobbler.
# 12311  [A] wily thriller, which revitalizes a familiar premise by turning it inside out.
# 12071  It's slickly done, pleasantly watchable, but despite Barrymore's ever-charming earnestness, not quite a home run.
# 7873   Producer Philip D'Antoni and screenwriter Ernest Tidyman have added enough fictional flesh to provide director William Friedkin and his overall topnotch cast with plenty of material, and they make the most of it.
# 11040  Heather's shaky video work can induce motion sickness -- it looks like combat footage as she bolts through the woods -- but just try turning away.
# 6616   The kind of bold, uncompromising film that insists on being thought about afterward -- talked about, argued about, hated if necessary, but not ignored.
# 13160  The Talented Mr. Ripley loses a bit of its steam toward the end, but Minghella has still delivered an extremely provocative and well-made film.
# 5802   Although I liked the special effects in the first movie, they were probably not the point; fans of the TV series wanted to see their favorite characters again, and Trek II understood that desire and acted on it.
# 13048  As with the original Fantasia, the new film is a mixture of artistically respectable and mediocre moments, which for overall ambition and range, has no parallel in the world of contemporary animation.
# 8518   Well acted and crafted but highly conventional.
# 12929  A calamity of miscasting and commercial concessions.
# 4889   Minor shortcomings in a rewarding film.
# 9055   The film is so ingratiatingly high-spirited, and the performances so full of sass and vigor, that in the long run it doesn't really matter much.
# 855    Though this scheme involves loads of important data, it manages to sound dopey all the same.
# 2928   I dislike sentimentality where it doesn't belong, but there's something brave about the way August Rush declares itself and goes all the way with coincidence, melodrama and skillful tear-jerking.
# 8678   Ms. Bassett portrays this high-strung superwoman with such intensity that she makes her almost believable.
# 5611   Mr. Hitchcock and his associates have constructed a horror film that should raise the hackles of the most courageous and put goose-pimples on the toughest hide.
# 7152   It's weirdly engaging, like its hero.
# 5893   Shameless laughs flow off the prefab assembly line with sufficient regularity to please audiences with a taste for comfortable tradition spiced with a bit of contempo naughtiness.
# 8180   A showcase for the buoyant, antic spirit of Jamie Lee Curtis.
# 3919   Capra is an old-time movie craftsman, the master of every trick in the bag, and in many ways he is more at home with the medium than any other Hollywood director. But all of his details give the impression of contrived effect.
# 9613   Maybe it's 50 years late, but we're finally getting to see Godzilla as it was meant to be seen.
# 10863  This is fascinating stuff and would be more so if the actors brought more energy to it.
# 7907   The battered Britons may have some excuse for enjoying this nostalgic re-creation of empire ideology, but what's ours?
# 11384  Junior Healy (Michael Oliver), problem child and the movies' best argument for infanticide, is back and no one is more surprised than I am.
# 11836  Director Pierce and Bienen and the expert cast engage us in the actuality of these rootless, hopeless, stoned-out lives without sentimentalizing or romanticizing them.
# 12405  The film is bad -- not good-bad, tacky-bad or fun-bad, just plain awful and nearly unwatchable.
# 8661   To be able to give this kind of stuff new and sympathetic twists is a tribute to Hughes' skill with narrative, and to Ringwald's magnetism as a performer.
# 5964   A tight, beautifully contained thriller that plunges four wonderful actors ... into dangerous territory.
# 9791   Shakespeare in Love is not a great film, but it's an excuse to have an evening of pure enjoyment with a little culture painlessly mixed in.
# 12115  Anouk Aimee has a mature beauty and an ability to project an inner quality that helps stave off the obvious banality of her character, and this goes too for the perceptive Jean-Louis Trintignant as the man.
# 8853   At the story level, Willow is turgid and relentlessly predictable.
# 5345   It's a howl from the heart, a relentlessly involving movie that gives a kid every reason to believe that he or she can come of age.
# 5526   An ingenious script, excellent special effects and photography, and superior acting, make it an endearing winner.
# 2222   Being an appealing, shallow goof-off can wear thin, and Shore seems incapable of carrying a movie, even when it's a 90-minute knock-off like this.
# 3531   This sixth installment, by far the worst in the series, is bland and deadening.
# 3477   I don't even know where to start.
# 8363   You could wish upon a star and not conjure up a more joyous animated movie than this graceful retelling of the Hans Christian Andersen tale.
# 9921   Millions of people read Harr's gripping bestseller, but Steven Zaillian may be the only one who didn't understand it.
# 6797   The best shot in this film is the first one. Not a good sign.
# 4025   A scrumptious tale of great food and grand passions.
# 11621  Still, the movie is pretty bad. It's Rush Hour meets 48 Hours meets Bad Boys except this time around there's only one bad boy and the script and direction are subpar.
# 425    Written and directed with quirky charm by Marleen Gorris.
# 7984   An iconic movie of the '80s, with all the unappealing baggage that suggests.
# 3176   The experience of watching Trainspotting -- the electric, nasty and slick descent into the milieu of young Scottish junkies -- is a little like speeding through the digestive tract of some voracious beast.
# 5139   This is the worst big budget summer release I've seen in some time.
# 4703   It is, in a word, exquisite.
# 3527   Run-of-the-mill horror item is notable only for final appearance of the late Donald Pleasance
# 5573   Barely watchable and not especially enjoyable.
# 11426  Teaching Mrs. Tingle reveals Williamson not only to be as accomplished a director as he is a writer but also his willingness to move beyond horror to psychological suspense.
# 12024  The Blue Lagoon is the dumbest movie of the year.
# 777    Has the strengths of Spike Lee's best work without the preachiness and gimmicky camera moves of his weakest.
# 2882   As the detective-story flashback structure gets under way, what initially seemed adherence to dramatic and moral cliche becomes more complex and interesting.
# 12859  A film that would inspire useful discussion in a history class, but for ordinary moviegoers, it's slow and forbidding.
# 6450   Loud, uninspired, and interminable.
# 13439  Splendidly shot by Sven Nykvist and with excellent performances, it's an agreeable puzzle which doesn't, thank heaven, come up with a solution to the meaning of life.
# 3801   The script lets too much slide, and director George Tillman Jr. -- whose biggest films have been Soul Food and the Barbershop franchise -- abets it.
# 11717  A markedly better picture than Roberto Benigni's far more sentimental Oscar collector.
# 12124  It's very pleased with itself.
# 1903   Producer-director-scripter Michael Corrente manages to bring freshness to basically derivative material in Federal Hill, thanks to a number of excellent performances and some evocative black-and-white images of a world he knows intimately.
# 4312   As a stand-up routine it's a scream.
# 1591   It's a successful frame-turner, no more, no less, and the pleasure we feel is every bit as mild and just as fleeting.
# 3633   Wilder's 1959 comedy is one of the enduring treasures of the movies, a film of inspiration and meticulous craft.
# 4834   Brazil is a stinging, Strangelovian satire of the power of the bureaucracy in an Orwellian landscape.
# 7359   Big, which has been directed by Penny Marshall with verve and impeccable judgment, drops a child's innocence into the corporate rat race as if it were a depth charge.
# 4874   [It] remains one of the most intelligent, handsome, and influential of all war epics.
# 1445   This excessively talky, incoherently plotted, would-be film noir is not very good.
# 5046   In a film of grand gestures, some of the finest moments are very subtle.
# 10568  Even if the script (written by the director and Mateo Gil) and direction are patchy, the obsessive theme is gripping.
# 10541  Once the thud of its wooden dialogue has settled into a deadly mechanical clomp -- about 10 minutes into the film -- you wonder why this risible movie didn't go straight to video.
# 4224   Sadly, Sheen doesn't even look profound. Like a zombie who's spent too much time in the gym, he blunders heavily from one stunt to the next, his pursed lips conveying nothing more than pique.
# 4692   In the director's cut, the film is not only a love song to the movies but it also is more fully an example of the kind of lush, all-enveloping movie experience it rhapsodizes.
# 8442   This is not a story that cries out to be remade every 15-20 years. And, while the special effects and acting are getting better, the story isn't.
# 8724   Hopelessly dated before its release.
# 8909   By common consent, one of Alfred Hitchcock's poorest and least personal works, though it has some compensations.
# 4018   Collins, who died at 31, was arguably the key figure in the struggles that led to the separation of Ireland and Britain. He was also, on the basis of this film, a man able to use violence without becoming intoxicated by it.
# 1025   Goldberg and Parker are extraordinary.
# 8715   The web of lies, failures and brutal revelations here is strong stuff, and it's the work of an original filmmaker who takes no prisoners.
# ...
# 6470   fresh
# 8633   fresh
# 4798   fresh
# 12539  rotten
# 2512   rotten
# 3574   fresh
# 10534  fresh
# 4776   fresh
# 10615  fresh
# 11627  rotten
# 3054   fresh
# 12936  fresh
# 5395   rotten
# 584    fresh
# 6460   rotten
# 9671   fresh
# 76     rotten
# 11563  fresh
# 3650   fresh
# 5481   fresh
# 2083   fresh
# 6570   fresh
# 3786   fresh
# 13076  fresh
# 854    fresh
# 12498  fresh
# 8015   fresh
# 12255  fresh
# 4021   fresh
# 13228  fresh
# 32     fresh
# 10540  fresh
# 11009  rotten
# 7955   fresh
# 10151  rotten
# 6897   fresh
# 8980   fresh
# 12351  rotten
# 2727   fresh
# 13435  rotten
# 9295   fresh
# 8992   rotten
# 2900   fresh
# 12661  rotten
# 13156  fresh
# 1705   rotten
# 9323   rotten
# 11878  fresh
# 1465   fresh
# 9249   rotten
# 7916   fresh
# 4066   fresh
# 13366  rotten
# 4814   fresh
# 13231  fresh
# 3321   rotten
# 2261   fresh
# 12464  rotten
# 5690   fresh
# 7043   fresh
# 3366   rotten
# 12399  fresh
# 12713  fresh
# 113    fresh
# 7164   fresh
# 4718   fresh
# 3177   fresh
# 1536   rotten
# 2707   fresh
# 9496   fresh
# 11313  fresh
# 12585  fresh
# 9524   fresh
# 1511   rotten
# 12121  rotten
# 11467  fresh
# 11205  fresh
# 2915   fresh
# 5563   fresh
# 12765  fresh
# 4507   fresh
# 13438  rotten
# 13201  rotten
# 9076   fresh
# 8668   rotten
# 3596   fresh
# 1760   fresh
# 5197   fresh
# 5449   fresh
# 3325   fresh
# 10187  rotten
# 4489   fresh
# 7673   fresh
# 592    fresh
# 11720  fresh
# 2925   rotten
# 3117   rotten
# 10218  rotten
# 9178   fresh
# 7859   fresh
# 1427   fresh
# 13032  fresh
# 4221   fresh
# 12610  fresh
# 5517   fresh
# 10239  rotten
# 2458   fresh
# 3417   fresh
# 12878  fresh
# 2413   fresh
# 7712   rotten
# 3080   rotten
# 9116   rotten
# 5255   fresh
# 7708   fresh
# 1657   fresh
# 10267  fresh
# 11130  rotten
# 8743   rotten
# 13427  fresh
# 11338  rotten
# 7692   rotten
# 3328   fresh
# 7173   fresh
# 9941   fresh
# 6778   fresh
# 8777   rotten
# 10518  fresh
# 7319   fresh
# 5831   rotten
# 10565  fresh
# 11651  fresh
# 7171   fresh
# 2912   fresh
# 9341   rotten
# 1459   rotten
# 11944  fresh
# 3525   rotten
# 10536  fresh
# 10126  fresh
# 10072  rotten
# 237    fresh
# 8728   rotten
# 5081   fresh
# 3155   rotten
# 10862  rotten
# 690    rotten
# 5151   rotten
# 2166   fresh
# 2085   fresh
# 903    fresh
# 3999   fresh
# 2559   fresh
# 1683   fresh
# 4440   fresh
# 6602   rotten
# 816    fresh
# 2550   fresh
# 3778   rotten
# 11641  rotten
# 6026   fresh
# 10293  rotten
# 5945   fresh
# 420    fresh
# 5934   rotten
# 1568   fresh
# 10213  fresh
# 6683   fresh
# 1863   fresh
# 11794  fresh
# 5820   fresh
# 10246  rotten
# 6529   fresh
# 12771  fresh
# 11260  fresh
# 11015  rotten
# 6670   fresh
# 7505   fresh
# 5051   fresh
# 1125   fresh
# 6788   fresh
# 2221   fresh
# 9054   fresh
# 11615  fresh
# 10626  fresh
# 1333   rotten
# 2317   fresh
# 5132   fresh
# 8816   fresh
# 8859   fresh
# 6914   fresh
# 4782   fresh
# 9307   rotten
# 8711   fresh
# 1887   fresh
# 7082   rotten
# 8281   rotten
# 2817   fresh
# 3534   fresh
# 7049   fresh
# 232    fresh
# 6075   rotten
# 5513   fresh
# 1975   fresh
# 6447   rotten
# 2068   rotten
# 9132   fresh
# 8732   rotten
# 1341   rotten
# 117    fresh
# 7563   rotten
# 10893  fresh
# 11629  rotten
# 5070   fresh
# 6829   rotten
# 12368  fresh
# 2054   rotten
# 4530   rotten
# 12107  rotten
# 439    fresh
# 1494   fresh
# 7643   rotten
# 82     fresh
# 6287   rotten
# 1153   rotten
# 3827   fresh
# 10036  fresh
# 11868  fresh
# 9537   fresh
# 1967   fresh
# 7909   fresh
# 6488   fresh
# 11611  rotten
# 2583   fresh
# 4272   fresh
# 5006   fresh
# 11768  fresh
# 2297   fresh
# 7001   fresh
# 9451   rotten
# 8002   fresh
# 3208   fresh
# 4274   fresh
# 5947   rotten
# 227    fresh
# 13006  fresh
# 7553   fresh
# 1712   fresh
# 7517   rotten
# 11184  rotten
# 3972   fresh
# 3821   fresh
# 109    rotten
# 11097  fresh
# 2992   fresh
# 4052   fresh
# 6591   rotten
# 2998   fresh
# 6380   fresh
# 4619   fresh
# 7750   fresh
# 8840   fresh
# 6021   fresh
# 6613   fresh
# 6872   fresh
# 3347   rotten
# 11000  fresh
# 529    fresh
# 4497   fresh
# 7237   fresh
# 11670  fresh
# 6336   fresh
# 819    rotten
# 10322  rotten
# 10763  fresh
# 5308   fresh
# 11860  rotten
# 10129  fresh
# 6224   fresh
# 4384   fresh
# 1330   fresh
# 2344   fresh
# 7045   fresh
# 5716   rotten
# 10302  fresh
# 2154   fresh
# 3771   fresh
# 3751   fresh
# 356    rotten
# 1359   fresh
# 573    fresh
# 1247   rotten
# 5218   fresh
# 12959  fresh
# 7678   rotten
# 13074  fresh
# 7368   fresh
# 3975   fresh
# 2841   rotten
# 7407   fresh
# 2524   fresh
# 5621   fresh
# 853    rotten
# 3114   rotten
# 13236  fresh
# 1935   rotten
# 11552  rotten
# 5794   rotten
# 9169   rotten
# 9837   rotten
# 6476   rotten
# 1882   rotten
# 5279   rotten
# 6002   fresh
# 6061   rotten
# 1677   rotten
# 1489   fresh
# 6859   fresh
# 10367  rotten
# 4350   fresh
# 12265  fresh
# 8624   fresh
# 5695   fresh
# 12514  rotten
# 527    fresh
# 10538  fresh
# 1660   fresh
# 7095   rotten
# 9914   fresh
# 6067   fresh
# 3589   fresh
# 11906  fresh
# 6866   fresh
# 31     fresh
# 11605  fresh
# 2258   fresh
# 12240  fresh
# 3688   fresh
# 11432  rotten
# 2734   fresh
# 241    fresh
# 9833   fresh
# 3939   fresh
# 450    fresh
# 5955   rotten
# 1470   fresh
# 12938  fresh
# 5417   fresh
# 5027   fresh
# 9591   fresh
# 6975   fresh
# 661    fresh
# 10351  fresh
# 10093  fresh
# 12900  fresh
# 7239   fresh
# 5605   fresh
# 13216  fresh
# 12206  fresh
# 4252   fresh
# 12041  fresh
# 8211   rotten
# 11396  rotten
# 8444   rotten
# 5925   fresh
# 12563  fresh
# 4228   rotten
# 8834   rotten
# 9042   rotten
# 11937  fresh
# 6635   rotten
# 1032   fresh
# 2684   rotten
# 5505   fresh
# 6828   rotten
# 12446  rotten
# 7533   fresh
# 9646   fresh
# 8680   fresh
# 5389   fresh
# 7349   fresh
# 8416   fresh
# 3728   fresh
# 3730   fresh
# 3254   fresh
# 6748   rotten
# 3291   fresh
# 3421   fresh
# 9900   fresh
# 12486  rotten
# 5064   fresh
# 12892  rotten
# 13301  rotten
# 11530  fresh
# 11531  fresh
# 4325   fresh
# 4181   fresh
# 1355   fresh
# 9278   rotten
# 5676   fresh
# 7541   rotten
# 10101  fresh
# 11783  fresh
# 11551  rotten
# 13     fresh
# 4785   fresh
# 7989   fresh
# 6530   fresh
# 12153  rotten
# 4771   fresh
# 2564   fresh
# 7870   fresh
# 10392  fresh
# 3392   rotten
# 8104   rotten
# 8628   rotten
# 11331  fresh
# 2634   fresh
# 615    fresh
# 1027   fresh
# 11736  rotten
# 8130   fresh
# 2960   fresh
# 5596   fresh
# 7417   rotten
# 2246   fresh
# 5762   fresh
# 7269   rotten
# 7198   fresh
# 1992   fresh
# 10388  rotten
# 830    fresh
# 10964  fresh
# 2726   fresh
# 7865   fresh
# 9982   rotten
# 7592   fresh
# 7432   rotten
# 4096   rotten
# 2893   fresh
# 4761   fresh
# 5956   fresh
# 7882   fresh
# 6497   fresh
# 5364   fresh
# 6779   fresh
# 5906   fresh
# 3136   fresh
# 189    fresh
# 6416   fresh
# 12168  fresh
# 1022   fresh
# 2442   rotten
# 2787   fresh
# 2778   fresh
# 7100   fresh
# 10204  fresh
# 2082   fresh
# 11340  rotten
# 5753   fresh
# 955    rotten
# 3687   fresh
# 256    fresh
# 8445   fresh
# 5303   fresh
# 806    rotten
# 7461   fresh
# 7967   fresh
# 6344   fresh
# 6098   rotten
# 10898  rotten
# 2211   fresh
# 3573   fresh
# 10779  fresh
# 11553  fresh
# 507    rotten
# 11434  rotten
# 10108  fresh
# 448    fresh
# 967    fresh
# 567    fresh
# 8240   fresh
# 1094   rotten
# 11139  rotten
# 7732   fresh
# 10088  rotten
# 4422   rotten
# 12595  fresh
# 7978   fresh
# 6761   fresh
# 11847  fresh
# 9316   fresh
# 3306   fresh
# 2096   rotten
# 4078   fresh
# 11069  rotten
# 596    rotten
# 4882   fresh
# 2990   fresh
# 224    fresh
# 5399   fresh
# 9511   fresh
# 6877   fresh
# 11274  fresh
# 10381  rotten
# 1314   fresh
# 1704   rotten
# 2906   rotten
# 9806   rotten
# 11142  fresh
# 5452   fresh
# 8907   rotten
# 12767  fresh
# 4837   fresh
# 7257   fresh
# 6656   fresh
# 6006   fresh
# 6120   fresh
# 7339   fresh
# 7552   fresh
# 1768   fresh
# 3928   rotten
# 2807   fresh
# 1775   rotten
# 4058   fresh
# 9733   rotten
# 1004   rotten
# 4934   fresh
# 9166   fresh
# 12667  fresh
# 3817   fresh
# 11309  rotten
# 2312   rotten
# 5570   rotten
# 10033  rotten
# 12261  fresh
# 10535  rotten
# 10091  rotten
# 697    fresh
# 11023  fresh
# 5115   rotten
# 9258   rotten
# 12458  fresh
# 9217   rotten
# 4486   fresh
# 3475   fresh
# 7137   rotten
# 2400   rotten
# 3675   fresh
# 1504   rotten
# 10481  fresh
# 12061  rotten
# 13089  rotten
# 536    fresh
# 9337   fresh
# 1305   fresh
# 3261   fresh
# 4860   fresh
# 2585   fresh
# 12768  rotten
# 12225  fresh
# 11315  fresh
# 7197   fresh
# 5891   fresh
# 2236   fresh
# 7528   fresh
# 2572   rotten
# 4525   rotten
# 2696   fresh
# 6799   rotten
# 6922   fresh
# 2672   fresh
# 2073   fresh
# 18     rotten
# 7580   fresh
# 12196  fresh
# 2324   fresh
# 11276  fresh
# 1195   rotten
# 10160  fresh
# 2475   rotten
# 625    fresh
# 298    fresh
# 5016   fresh
# 4845   fresh
# 12487  rotten
# 1261   rotten
# 543    fresh
# 6405   rotten
# 1128   fresh
# 6150   rotten
# 3804   fresh
# 7535   fresh
# 6337   fresh
# 10962  fresh
# 781    fresh
# 7233   fresh
# 4931   fresh
# 10460  fresh
# 11226  rotten
# 10691  fresh
# 7077   rotten
# 767    fresh
# 4121   fresh
# 3418   fresh
# 2804   fresh
# 3561   fresh
# 7710   fresh
# 8064   fresh
# 1876   rotten
# 13410  fresh
# 7630   fresh
# 225    fresh
# 9785   fresh
# 2689   fresh
# 3873   fresh
# 6585   fresh
# 2269   fresh
# 8156   rotten
# 104    rotten
# 3526   rotten
# 246    fresh
# 2283   fresh
# 12134  rotten
# 5229   fresh
# 4131   rotten
# 10206  fresh
# 4861   fresh
# 10600  fresh
# 12581  fresh
# 626    rotten
# 2114   fresh
# 4474   rotten
# 8541   fresh
# 5346   fresh
# 9367   rotten
# 11214  fresh
# 12027  fresh
# 5148   rotten
# 4603   rotten
# 9820   rotten
# 11358  fresh
# 11266  fresh
# 5734   rotten
# 6949   rotten
# 7008   fresh
# 5975   fresh
# 7016   fresh
# 1216   fresh
# 5829   rotten
# 1306   rotten
# 8681   rotten
# 8131   rotten
# 9322   fresh
# 1165   rotten
# 3313   fresh
# 8067   rotten
# 9585   fresh
# 5555   fresh
# 1105   fresh
# 10069  fresh
# 7815   fresh
# 3463   rotten
# 1569   rotten
# 7430   rotten
# 12549  fresh
# 13383  rotten
# 2329   fresh
# 5825   fresh
# 2664   rotten
# 12795  fresh
# 11052  rotten
# 12194  fresh
# 1371   fresh
# 9041   fresh
# 9338   fresh
# 7632   rotten
# 1186   rotten
# 3342   fresh
# 12569  fresh
# 12911  fresh
# 1142   fresh
# 5328   fresh
# 12948  rotten
# 1168   fresh
# 6454   rotten
# 3386   rotten
# 5414   fresh
# 2376   rotten
# 7020   fresh
# 9676   fresh
# 8918   fresh
# 3002   rotten
# 2856   rotten
# 11592  fresh
# 7103   fresh
# 13092  fresh
# 459    rotten
# 1152   fresh
# 3942   fresh
# 7953   fresh
# 3217   rotten
# 12869  fresh
# 7843   fresh
# 2745   fresh
# 4148   fresh
# 3399   fresh
# 4061   fresh
# 10880  fresh
# 8564   fresh
# 2281   fresh
# 9583   fresh
# 9243   rotten
# 2558   fresh
# 11788  fresh
# 8074   fresh
# 12393  fresh
# 11429  rotten
# 4536   fresh
# 5582   rotten
# 5842   rotten
# 2155   fresh
# 13377  rotten
# 3575   fresh
# 562    fresh
# 5694   fresh
# 6124   fresh
# 10628  fresh
# 834    rotten
# 6424   fresh
# 1514   rotten
# 12994  rotten
# 5174   fresh
# 5386   fresh
# 2810   fresh
# 12431  fresh
# 4002   fresh
# 3554   fresh
# 12807  fresh
# 9248   fresh
# 13227  rotten
# 10639  fresh
# 4813   fresh
# 2633   fresh
# 7429   rotten
# 183    fresh
# 7175   rotten
# 5309   fresh
# 1802   rotten
# 371    fresh
# 9122   fresh
# 5040   fresh
# 8182   fresh
# 7167   fresh
# 11977  fresh
# 9444   fresh
# 10558  fresh
# 5383   fresh
# 8082   fresh
# 6394   fresh
# 6932   rotten
# 9435   fresh
# 8247   rotten
# 2386   fresh
# 6352   fresh
# 7668   fresh
# 9635   fresh
# 7806   fresh
# 6456   rotten
# 3314   rotten
# 414    fresh
# 9052   fresh
# 1523   fresh
# 8544   fresh
# 9904   rotten
# 5071   fresh
# 10079  fresh
# 4385   fresh
# 798    fresh
# 11166  fresh
# 1787   fresh
# 13294  fresh
# 8844   fresh
# 1342   rotten
# 1450   fresh
# 5142   fresh
# 6043   rotten
# 9183   fresh
# 2005   rotten
# 12578  rotten
# 6692   rotten
# 7816   fresh
# 5189   fresh
# 5791   rotten
# 7286   fresh
# 13285  fresh
# 7048   fresh
# 5685   fresh
# 12655  fresh
# 520    fresh
# 1856   fresh
# 10660  fresh
# 10234  fresh
# 3937   fresh
# 6523   rotten
# 3150   fresh
# 2924   fresh
# 5161   fresh
# 10178  fresh
# 10958  fresh
# 6225   rotten
# 489    fresh
# 2173   rotten
# 2971   fresh
# 9134   fresh
# 4056   fresh
# 9802   fresh
# 2730   rotten
# 11333  fresh
# 3844   fresh
# 1730   fresh
# 3994   fresh
# 6547   fresh
# 3187   rotten
# 12233  fresh
# 10345  fresh
# 2194   fresh
# 13387  rotten
# 11030  rotten
# 6610   fresh
# 3859   fresh
# 5594   fresh
# 9079   fresh
# 4302   fresh
# 3086   rotten
# 1535   fresh
# 218    fresh
# 20     fresh
# 6172   rotten
# 8489   rotten
# 4495   fresh
# 9179   fresh
# 10112  rotten
# 3238   fresh
# 12396  rotten
# 11244  fresh
# 8653   fresh
# 10517  rotten
# 8367   fresh
# 2434   rotten
# 2023   rotten
# 1492   fresh
# 6896   fresh
# 9952   fresh
# 2954   fresh
# 7299   fresh
# 5029   fresh
# 2200   rotten
# 13099  fresh
# 3921   fresh
# 9552   fresh
# 10419  rotten
# 5822   fresh
# 9211   fresh
# 2000   fresh
# 1104   rotten
# 641    rotten
# 2242   fresh
# 1277   rotten
# 12159  rotten
# 10385  rotten
# 7948   fresh
# 9296   fresh
# 6787   fresh
# 4515   rotten
# 5073   fresh
# 11902  fresh
# 11656  fresh
# 634    rotten
# 9114   fresh
# 7761   fresh
# 6484   rotten
# 1328   fresh
# 9901   fresh
# 1017   rotten
# 2056   rotten
# 10861  rotten
# 927    rotten
# 5307   fresh
# 7283   rotten
# 1175   rotten
# 8264   fresh
# 4468   fresh
# 7698   fresh
# 5501   fresh
# 9670   fresh
# 9939   fresh
# 3870   fresh
# 4122   fresh
# 11756  fresh
# 8222   fresh
# 11905  fresh
# 10171  fresh
# 6518   fresh
# 2608   rotten
# 2435   rotten
# 10602  fresh
# 7621   fresh
# 5423   fresh
# 10441  fresh
# 8495   fresh
# 12903  fresh
# 7851   rotten
# 828    fresh
# 1005   fresh
# 604    fresh
# 4137   fresh
# 3330   rotten
# 5567   fresh
# 6825   rotten
# 11207  fresh
# 2752   fresh
# 12227  rotten
# 4568   fresh
# 5972   fresh
# 2640   fresh
# 10544  rotten
# 10199  fresh
# 1057   fresh
# 13016  fresh
# 11727  fresh
# 3884   fresh
# 4344   fresh
# 12868  fresh
# 10922  fresh
# 7529   fresh
# 10845  fresh
# 10275  fresh
# 6678   fresh
# 5136   fresh
# 6838   rotten
# 10191  rotten
# 12409  rotten
# 5534   fresh
# 3568   fresh
# 5210   fresh
# 10622  fresh
# 9071   fresh
# 733    rotten
# 484    fresh
# 839    fresh
# 717    fresh
# 3368   rotten
# 2349   fresh
# 8327   fresh
# 2883   fresh
# 3188   rotten
# 12957  rotten
# 11941  fresh
# 6890   rotten
# 969    fresh
# 10769  fresh
# 5500   fresh
# 7637   fresh
# 11411  fresh
# 6163   fresh
# 9415   rotten
# 6422   fresh
# 2483   fresh
# 145    fresh
# 12572  fresh
# 8986   fresh
# 10071  rotten
# 10610  rotten
# 7285   fresh
# 7742   rotten
# 12721  fresh
# 679    rotten
# 12809  rotten
# 1237   fresh
# 2788   fresh
# 1786   fresh
# 6723   fresh
# 1930   fresh
# 2012   fresh
# 4356   fresh
# 1961   fresh
# 2876   fresh
# 3753   fresh
# 9499   rotten
# 6095   rotten
# 10646  rotten
# 9205   fresh
# 2395   fresh
# 8568   fresh
# 9892   rotten
# 5700   fresh
# 9085   rotten
# 6494   rotten
# 11942  fresh

# %% [markdown]
# If categorical variable has a category (in test data set), which was not observed in training data set, then model will assign a 0 (zero) probability and will be unable to make a prediction. This can be reason why these are missclassified.
#
# This is often known as “Zero Frequency”. To solve this, we can use the smoothing technique.
#
# The other reason that the quotes are getting misclassified is the figure of speech in the language English. Usage of both positive and negative words(Oxymoron) makes the classfier misjudge. For example - "It's easy to admire what the Coens are trying to do in Fargo, but more difficult to actually like the film." It uses easy, admire and at the same time difficult.
# In certain cases, the author is talking about not the movie, but the actors involved, which may not be picked up by the classified. For example -"Boring as it may have become for Meryl Streep to show up for awards ceremonies, count on her to be doing it again."

# %% [markdown]
# # 4 NB with Smoothing

# %% [markdown]
# So, now you have your brand-new NB algorithm up and running. As a next step, we add smoothing to it. As our task is to find the best smoothing parameter below, your first task is to mold what you did above into two functions: one for fitting and another one for predicting.

# %% [markdown]
# 1. Create two functions: one for fitting NB model, and another to predict outcome based on the fitted model.
# As mentioned above, the model is fully described with 4 probabilities, so your fitting function may return such a list as the model; and the prediction function may take it as an input.

# %%
def fitting_nb_model(train_x, train_y):
    """This function takes the training data and 
    returns the apriori probabilities needed for naive bayes calcs"""
    #calculating log probability that the review is fresh
    prF = np.log(len(train_y[train_y=='fresh'])/len(train_y))
    #calculating log probability that the review is rotten
    prR = np.log(len(train_y[train_y=='rotten'])/len(train_y))
    
    # get the number of fresh and rotten reviews on the training set
    fresh_count = train_x[np.where(train_y == 'fresh')].shape[0]
    rotten_count = train_x[np.where(train_y == 'rotten')].shape[0]
    
    # get conditional log probabilties 
    # condition log probability of word when review is fresh
    prWF = np.log(train_x[np.where(train_y == 'fresh')].toarray().sum(axis=0) / fresh_count)
    # condition log probability of word when review is rotten
    prWR = np.log(train_x[np.where(train_y == 'rotten')].toarray().sum(axis=0) / rotten_count)
    
    model_list = [prF, prR, prWF, prWR]
    return model_list

# %%
def predict_outcome(model_list,data):
    """ This function predicts the naive bayes results based on conditional probabilities passed to it"""
    arr_val_x = data.toarray()
    log_likehood_F = []
    log_likehood_R = []
    prF = model_list[0]
    prR = model_list[1]
    prWF = model_list[2]
    prWR = model_list[3]
    
    for word_index in np.arange(arr_val_x.shape[0]):
        val_text = arr_val_x[word_index]
        prTextF = 0.0
        prTextR = 0.0
        for index, word in enumerate(val_text,start=0):
            if word == 0:
                continue
            prTextF += prWF[index]
            prTextR += prWR[index]
        prTextF += prF
        prTextR += prR
        log_likehood_F.append(prTextF)
        log_likehood_R.append(prTextR)
        
    predicted_target = []
    
    for index in np.arange(len(log_likehood_F)):
        if log_likehood_F[index] > log_likehood_R[index]:
            predicted_target.append('fresh')
        else:
            predicted_target.append('rotten')
    
    predicted_target = np.array(predicted_target)
    return predicted_target

# %% [markdown]
# 2. Add smoothing to the model. See Schutt p 103 and 109. Smoothing amounts to assuming that we have seen every possible word α >= 0 times already, for both classes. (If you wish, you can also assume you have seen the words α times for F and β times for R). Note that α does not have to be an integer, and typically the best α < 1.

# %%
def fitting_nb_model(train_x, train_y,smoothing):
    """This function takes the training data and 
    returns the apriori probabilities needed for naive bayes calcs"""
    #calculating log probability that the review is fresh
    prF = np.log(len(train_y[train_y=='fresh'])/len(train_y))
    #calculating log probability that the review is rotten
    prR = np.log(len(train_y[train_y=='rotten'])/len(train_y))
    
    # get the number of fresh and rotten reviews on the training set
    fresh_count = train_x[np.where(train_y == 'fresh')].shape[0]
    rotten_count = train_x[np.where(train_y == 'rotten')].shape[0]
    
    # get conditional log probabilties 
    # condition log probability of word when review is fresh
    prWF = np.log(np.add(train_x[np.where(train_y == 'fresh')].toarray().sum(axis=0),smoothing) / fresh_count)
    # condition log probability of word when review is rotten
    prWR = np.log(np.add(train_x[np.where(train_y == 'rotten')].toarray().sum(axis=0),smoothing) / rotten_count)
    model_list = [prF, prR, prWF, prWR]
    return model_list

# %%
train_x,val_x,train_y,val_y = train_test_split(X, Y, test_size = 0.5)
model_list = fitting_nb_model(train_x, train_y,0.1)
predicted_target = predict_outcome(model_list,val_x)
print(confusion_matrix(val_y, predicted_target))
print(accuracy_score(val_y, predicted_target))
# Out:
# [[3183  840]
#  [ 948 1441]]
# 0.7211478477854024

# %% [markdown]
# 3. Cross-validate the accuracy (on the validation data) on a number of α values and find the α that gives you the best result. You can use your own CV algorithm you created for PS4, or an existing library.

# %%
from sklearn.model_selection import KFold
from statistics import mean 
from sklearn.model_selection import LeaveOneOut 
kf = KFold(n_splits=5)

smoothing = np.arange(0.1,1,0.1)
abc = None

for alpha in smoothing:
    accuracy = list()
    for train_index, test_index in kf.split(val_x):
        train_x, x_val = val_x[train_index], val_x[test_index]
        train_y, y_val = val_y.iloc[train_index], val_y.iloc[test_index]
        model_list = fitting_nb_model(train_x, train_y,alpha)
        predictions = predict_outcome(model_list,x_val)
        abc = predictions
        fold_accuracy = accuracy_score(y_val, predictions)
#         print(fold_accuracy)
        accuracy.append(fold_accuracy)
    print("For smoothing parameter =",alpha)
    print("Accuracy score:",mean(accuracy))
    print()
# Out:
# For smoothing parameter = 0.1
# Accuracy score: 0.7138203532817852
#
# For smoothing parameter = 0.2
# Accuracy score: 0.7147552963692982
#
# For smoothing parameter = 0.30000000000000004
# Accuracy score: 0.7117916641841044
#
# For smoothing parameter = 0.4
# Accuracy score: 0.7107001068819059
#
# For smoothing parameter = 0.5
# Accuracy score: 0.7080493383414215
#
# For smoothing parameter = 0.6
# Accuracy score: 0.7025907006662184
#
# For smoothing parameter = 0.7000000000000001
# Accuracy score: 0.6979120941922634
#
# For smoothing parameter = 0.8
# Accuracy score: 0.6943245586409582
#
# For smoothing parameter = 0.9
# Accuracy score: 0.6904256185835898

# %% [markdown]
# The value of alpha that gives the best result is at alpha = 0.2. The lower the value of alpha, the results are better and the accuracy keeps decresing as the value of alpha is increased.
